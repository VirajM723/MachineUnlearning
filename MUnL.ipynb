# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error
from torchsummary import summary

# %%
df = pd.read_csv('fnma loan data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Enterprise Flag', 'Record Number',
#        'US Postal State Code', 'Metropolitan Statistical Area (MSA) Code',
#        'County - 2010 Census', 'Census Tract - 2010 Census',
#        '2010 Census Tract - Percent Minority',
#        '2010 Census Tract - Median Income', 'Local Area Median Income',
#        'Tract Income Ratio', 'Borrower’s (or Borrowers’) Annual Income',
#        'Area Median Family Income (2016)', 'Borrower Income Ratio',
#        'Acquisition Unpaid Principal Balance (UPB)', 'Purpose of Loan',
#        'Federal Guarantee', 'Number of Borrowers', 'First-Time Home Buyer',
#        'Borrower Race or National Origin 1-5 #1',
#        'Borrower Race or National Origin 1-5 #2',
#        'Borrower Race or National Origin 1-5 #3',
#        'Borrower Race or National Origin 1-5 #4',
#        'Borrower Race or National Origin 1-5 #5', 'Borrower Ethnicity',
#        'Co-Borrower Race or National Origin 1-5 #1',
#        'Co-Borrower Race or National Origin 1-5 #2',
#        'Co-Borrower Race or National Origin 1-5 #3',
#        'Co-Borrower Race or National Origin 1-5 #4',
#        'Co-Borrower Race or National Origin 1-5 #5', 'Co-Borrower Ethnicity',
#        'Borrower Gender', 'Co-Borrower Gender', 'Age of Borrower',
#        'Age of Co-Borrower', 'Occupancy Code', 'Rate Spread', 'HOEPA Status',
#        'Property Type', 'Lien Status'],
#       dtype='object')

# %%
# Creaitng the features and target from the dataset
features_list = [
    'Record Number',
    "Borrower’s (or Borrowers’) Annual Income",
    "Area Median Family Income (2016)",
    "Tract Income Ratio",
    "2010 Census Tract - Median Income",
    "Purpose of Loan",
    "Number of Borrowers",
    "First-Time Home Buyer",
    "Federal Guarantee",
    "Property Type",
    "Rate Spread",
    "Occupancy Code",
    "US Postal State Code",
    "Metropolitan Statistical Area (MSA) Code",
    "Lien Status"
]

features = df[features_list].values
target = df['Acquisition Unpaid Principal Balance (UPB)'].values

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=42)

# %%
l = []
for i in X_train:
    l.append(i[0])
l
# Out:
# [32918.0,
#  2211582.0,
#  1348329.0,
#  773432.0,
#  477310.0,
#  2504328.0,
#  841081.0,
#  751420.0,
#  619468.0,
#  2252102.0,
#  1505482.0,
#  2523976.0,
#  2125968.0,
#  1358094.0,
#  951342.0,
#  1109194.0,
#  2277829.0,
#  1571646.0,
#  2169023.0,
#  2085217.0,
#  440661.0,
#  2403812.0,
#  1006178.0,
#  193043.0,
#  192142.0,
#  203476.0,
#  451561.0,
#  1877158.0,
#  1113810.0,
#  1417677.0,
#  2221059.0,
#  2283044.0,
#  2074821.0,
#  1962705.0,
#  2385017.0,
#  1096649.0,
#  2310528.0,
#  106544.0,
#  2402022.0,
#  2260685.0,
#  2346018.0,
#  326758.0,
#  732239.0,
#  2103273.0,
#  594185.0,
#  247736.0,
#  1449856.0,
#  709608.0,
#  611656.0,
#  536142.0,
#  1785955.0,
#  415942.0,
#  1899943.0,
#  1590780.0,
#  1392923.0,
#  543800.0,
#  901128.0,
#  92232.0,
#  2267549.0,
#  56325.0,
#  731121.0,
#  1424088.0,
#  1930796.0,
#  865503.0,
#  2447264.0,
#  951683.0,
#  1460469.0,
#  1253455.0,
#  2265579.0,
#  741780.0,
#  2215658.0,
#  2321895.0,
#  2473034.0,
#  644280.0,
#  887496.0,
#  805539.0,
#  2396964.0,
#  876369.0,
#  1157231.0,
#  2167497.0,
#  1898880.0,
#  121906.0,
#  667201.0,
#  1849447.0,
#  1297481.0,
#  75336.0,
#  795759.0,
#  772076.0,
#  1032121.0,
#  2187318.0,
#  1211697.0,
#  1603327.0,
#  2437356.0,
#  2270421.0,
#  1730996.0,
#  2237796.0,
#  2198760.0,
#  392697.0,
#  1674862.0,
#  100356.0,
#  488784.0,
#  2049654.0,
#  1850619.0,
#  150744.0,
#  2484631.0,
#  1799631.0,
#  450477.0,
#  2386664.0,
#  419678.0,
#  690069.0,
#  375316.0,
#  1168347.0,
#  1739209.0,
#  2289554.0,
#  1341321.0,
#  154762.0,
#  1754647.0,
#  2245832.0,
#  1130719.0,
#  241837.0,
#  2263888.0,
#  2046338.0,
#  1326690.0,
#  732157.0,
#  1722989.0,
#  57692.0,
#  1610520.0,
#  861642.0,
#  1333059.0,
#  521979.0,
#  2439357.0,
#  2181915.0,
#  1586416.0,
#  1204931.0,
#  1497679.0,
#  1504672.0,
#  1180589.0,
#  1886422.0,
#  2279727.0,
#  1986459.0,
#  2123148.0,
#  1542131.0,
#  1994812.0,
#  483537.0,
#  455799.0,
#  944223.0,
#  659089.0,
#  651931.0,
#  2365353.0,
#  1146741.0,
#  694216.0,
#  1574427.0,
#  933383.0,
#  446933.0,
#  34812.0,
#  1640787.0,
#  2439076.0,
#  72797.0,
#  961029.0,
#  2274166.0,
#  246138.0,
#  576356.0,
#  1416790.0,
#  543315.0,
#  104273.0,
#  82412.0,
#  1583913.0,
#  2437217.0,
#  798354.0,
#  142475.0,
#  320837.0,
#  778363.0,
#  807017.0,
#  2359472.0,
#  1207685.0,
#  2338394.0,
#  1214056.0,
#  1953938.0,
#  2015650.0,
#  1048128.0,
#  2187794.0,
#  2475647.0,
#  404659.0,
#  2313638.0,
#  323137.0,
#  246827.0,
#  2475621.0,
#  2077581.0,
#  2033586.0,
#  1414729.0,
#  252601.0,
#  1975083.0,
#  1314604.0,
#  1221912.0,
#  768079.0,
#  1627867.0,
#  1804599.0,
#  836324.0,
#  476435.0,
#  329269.0,
#  2054135.0,
#  591422.0,
#  212868.0,
#  785012.0,
#  222031.0,
#  331100.0,
#  1470569.0,
#  37089.0,
#  2359566.0,
#  2495248.0,
#  748602.0,
#  2050540.0,
#  2031369.0,
#  793520.0,
#  1449305.0,
#  1118999.0,
#  1367875.0,
#  2356032.0,
#  498338.0,
#  600430.0,
#  1461198.0,
#  1207701.0,
#  220377.0,
#  820982.0,
#  1876195.0,
#  333166.0,
#  1962040.0,
#  1856326.0,
#  2430261.0,
#  975935.0,
#  132963.0,
#  2318436.0,
#  365136.0,
#  1623727.0,
#  142680.0,
#  887433.0,
#  502744.0,
#  644131.0,
#  1653286.0,
#  730174.0,
#  2059590.0,
#  424505.0,
#  509598.0,
#  2502163.0,
#  2468872.0,
#  830423.0,
#  115670.0,
#  1790912.0,
#  317900.0,
#  2280270.0,
#  1045992.0,
#  1020623.0,
#  242863.0,
#  639077.0,
#  416718.0,
#  1984753.0,
#  1956636.0,
#  566269.0,
#  1217278.0,
#  2165166.0,
#  1256489.0,
#  2375106.0,
#  1914659.0,
#  39550.0,
#  1649298.0,
#  1558708.0,
#  892174.0,
#  694616.0,
#  1245325.0,
#  34090.0,
#  556356.0,
#  545503.0,
#  1703102.0,
#  2239154.0,
#  2222206.0,
#  2403161.0,
#  795560.0,
#  2053205.0,
#  669942.0,
#  614756.0,
#  1391296.0,
#  554988.0,
#  173400.0,
#  1792162.0,
#  499759.0,
#  228621.0,
#  952163.0,
#  2338500.0,
#  737401.0,
#  675601.0,
#  1450865.0,
#  509921.0,
#  1627074.0,
#  849748.0,
#  1301998.0,
#  209063.0,
#  66470.0,
#  261917.0,
#  1092601.0,
#  1346660.0,
#  1179641.0,
#  314859.0,
#  1973289.0,
#  1458689.0,
#  1580352.0,
#  104074.0,
#  2176819.0,
#  2100431.0,
#  622274.0,
#  2153849.0,
#  2227979.0,
#  2075923.0,
#  165978.0,
#  24883.0,
#  757665.0,
#  1678000.0,
#  1901538.0,
#  1628022.0,
#  414254.0,
#  264301.0,
#  851914.0,
#  2497240.0,
#  589092.0,
#  200295.0,
#  1077306.0,
#  763053.0,
#  2288795.0,
#  1629393.0,
#  436405.0,
#  1863363.0,
#  576078.0,
#  1341192.0,
#  2347644.0,
#  1756523.0,
#  238695.0,
#  1221101.0,
#  1364731.0,
#  360505.0,
#  1293008.0,
#  1415957.0,
#  2385848.0,
#  1022144.0,
#  2297179.0,
#  2225161.0,
#  1185865.0,
#  1744438.0,
#  865278.0,
#  947488.0,
#  699708.0,
#  2046612.0,
#  1234360.0,
#  822592.0,
#  1095825.0,
#  1318597.0,
#  555579.0,
#  1727404.0,
#  1891278.0,
#  1948031.0,
#  411720.0,
#  1340989.0,
#  2220655.0,
#  1250158.0,
#  2361094.0,
#  1997121.0,
#  1106699.0,
#  2051176.0,
#  406519.0,
#  2202419.0,
#  771135.0,
#  993543.0,
#  1577792.0,
#  1229647.0,
#  1949004.0,
#  484155.0,
#  1132262.0,
#  1530572.0,
#  2049221.0,
#  952835.0,
#  2251403.0,
#  881654.0,
#  547142.0,
#  813540.0,
#  489654.0,
#  1276753.0,
#  974808.0,
#  1383858.0,
#  2268628.0,
#  1867842.0,
#  2242746.0,
#  2073183.0,
#  1669749.0,
#  396338.0,
#  1207968.0,
#  517212.0,
#  349766.0,
#  769641.0,
#  2355036.0,
#  152184.0,
#  446985.0,
#  1684968.0,
#  1575412.0,
#  1172936.0,
#  969866.0,
#  321464.0,
#  280844.0,
#  2013103.0,
#  1157848.0,
#  1974951.0,
#  1192421.0,
#  986928.0,
#  1542702.0,
#  2464483.0,
#  777942.0,
#  1429281.0,
#  226127.0,
#  1528530.0,
#  1750744.0,
#  669763.0,
#  1881534.0,
#  238622.0,
#  843230.0,
#  5398.0,
#  415295.0,
#  740570.0,
#  2299088.0,
#  1765802.0,
#  1860152.0,
#  1258742.0,
#  219725.0,
#  409753.0,
#  1988132.0,
#  1280442.0,
#  1509940.0,
#  2461798.0,
#  710069.0,
#  2225027.0,
#  1011940.0,
#  902088.0,
#  2373832.0,
#  2457544.0,
#  1679607.0,
#  1701337.0,
#  2389434.0,
#  2525796.0,
#  375145.0,
#  228929.0,
#  1187371.0,
#  1291964.0,
#  1903446.0,
#  903834.0,
#  2193342.0,
#  1017180.0,
#  2530165.0,
#  210641.0,
#  1527275.0,
#  1414959.0,
#  1405665.0,
#  712036.0,
#  616672.0,
#  2058111.0,
#  428388.0,
#  241811.0,
#  1747577.0,
#  696534.0,
#  1255870.0,
#  520092.0,
#  1365229.0,
#  916093.0,
#  1524984.0,
#  180473.0,
#  868187.0,
#  2023875.0,
#  294594.0,
#  839384.0,
#  785080.0,
#  700694.0,
#  253542.0,
#  2359241.0,
#  972910.0,
#  407502.0,
#  1521762.0,
#  2336604.0,
#  939924.0,
#  1284990.0,
#  1455640.0,
#  1458.0,
#  1337193.0,
#  2104197.0,
#  777409.0,
#  1226837.0,
#  470507.0,
#  1433351.0,
#  1890449.0,
#  1133107.0,
#  2457569.0,
#  65708.0,
#  635940.0,
#  913394.0,
#  1989092.0,
#  360220.0,
#  1317985.0,
#  781834.0,
#  349566.0,
#  635616.0,
#  917298.0,
#  1016502.0,
#  2413768.0,
#  1410684.0,
#  2044261.0,
#  1782706.0,
#  893340.0,
#  1471638.0,
#  534474.0,
#  1556685.0,
#  1703636.0,
#  1333910.0,
#  2077535.0,
#  1058415.0,
#  1479298.0,
#  2129703.0,
#  917890.0,
#  1434207.0,
#  744499.0,
#  890627.0,
#  741831.0,
#  916673.0,
#  1826279.0,
#  2178026.0,
#  1192352.0,
#  2521747.0,
#  912879.0,
#  1877132.0,
#  2177420.0,
#  2183501.0,
#  1808040.0,
#  451653.0,
#  2091764.0,
#  2404586.0,
#  818400.0,
#  661776.0,
#  1497184.0,
#  2523136.0,
#  1210684.0,
#  1266660.0,
#  2237243.0,
#  807523.0,
#  550905.0,
#  532208.0,
#  1060229.0,
#  1764890.0,
#  250513.0,
#  1527239.0,
#  1402416.0,
#  680777.0,
#  2234722.0,
#  589451.0,
#  1421900.0,
#  2192704.0,
#  1138150.0,
#  1405750.0,
#  831189.0,
#  498139.0,
#  1293851.0,
#  473441.0,
#  62528.0,
#  392574.0,
#  887708.0,
#  1871621.0,
#  2503007.0,
#  1927495.0,
#  676772.0,
#  333307.0,
#  260144.0,
#  2216805.0,
#  2385426.0,
#  748313.0,
#  736179.0,
#  2278755.0,
#  1285213.0,
#  1488211.0,
#  1869978.0,
#  1093775.0,
#  1357055.0,
#  2039068.0,
#  800997.0,
#  395032.0,
#  1565716.0,
#  1821847.0,
#  669434.0,
#  369780.0,
#  277447.0,
#  2183749.0,
#  2165264.0,
#  859635.0,
#  268083.0,
#  1183504.0,
#  853757.0,
#  406831.0,
#  457070.0,
#  1287427.0,
#  64758.0,
#  490171.0,
#  607011.0,
#  1766310.0,
#  280670.0,
#  1513466.0,
#  499761.0,
#  2530529.0,
#  535755.0,
#  479594.0,
#  1101157.0,
#  872159.0,
#  2120813.0,
#  980577.0,
#  1866409.0,
#  1429817.0,
#  194089.0,
#  1157275.0,
#  2524630.0,
#  657896.0,
#  1053672.0,
#  666976.0,
#  2368762.0,
#  2356984.0,
#  2034520.0,
#  2202391.0,
#  705918.0,
#  201487.0,
#  1519914.0,
#  1945772.0,
#  1445419.0,
#  842530.0,
#  1138124.0,
#  1855699.0,
#  2119702.0,
#  1133853.0,
#  119544.0,
#  2498198.0,
#  2069378.0,
#  1309125.0,
#  1249894.0,
#  1397291.0,
#  905871.0,
#  1534546.0,
#  1195078.0,
#  1468886.0,
#  1112017.0,
#  1914076.0,
#  1945366.0,
#  415545.0,
#  1113502.0,
#  89021.0,
#  1371080.0,
#  2109776.0,
#  722231.0,
#  89254.0,
#  418337.0,
#  2278708.0,
#  272281.0,
#  27311.0,
#  2401834.0,
#  124399.0,
#  2497124.0,
#  1825117.0,
#  2166860.0,
#  588520.0,
#  1183382.0,
#  2366904.0,
#  1011349.0,
#  2033879.0,
#  1238499.0,
#  2222724.0,
#  607589.0,
#  1323591.0,
#  2059326.0,
#  801570.0,
#  1462905.0,
#  1337813.0,
#  890030.0,
#  324136.0,
#  605945.0,
#  1700211.0,
#  2195678.0,
#  1230741.0,
#  131001.0,
#  2522669.0,
#  1387699.0,
#  6882.0,
#  1204243.0,
#  2036606.0,
#  539704.0,
#  2050360.0,
#  1979603.0,
#  1241123.0,
#  2066941.0,
#  123434.0,
#  690543.0,
#  57712.0,
#  2107097.0,
#  2009335.0,
#  894321.0,
#  287614.0,
#  2406215.0,
#  1897590.0,
#  1320104.0,
#  148192.0,
#  798913.0,
#  1219274.0,
#  1733815.0,
#  1082396.0,
#  1163251.0,
#  1127287.0,
#  1165401.0,
#  307250.0,
#  1829281.0,
#  377207.0,
#  454545.0,
#  1224137.0,
#  977746.0,
#  756323.0,
#  1168280.0,
#  40198.0,
#  2121620.0,
#  511254.0,
#  162767.0,
#  1665898.0,
#  549388.0,
#  2316790.0,
#  438777.0,
#  2123889.0,
#  285778.0,
#  1370875.0,
#  196755.0,
#  2017383.0,
#  914143.0,
#  2053479.0,
#  1400564.0,
#  714189.0,
#  1669516.0,
#  540861.0,
#  2082521.0,
#  2473233.0,
#  1691035.0,
#  1945306.0,
#  811242.0,
#  103816.0,
#  912864.0,
#  708000.0,
#  60808.0,
#  880034.0,
#  343826.0,
#  2295440.0,
#  2061003.0,
#  1439669.0,
#  14083.0,
#  352782.0,
#  1815867.0,
#  829868.0,
#  723966.0,
#  699259.0,
#  1476411.0,
#  1648734.0,
#  380241.0,
#  2497818.0,
#  514100.0,
#  2013340.0,
#  836226.0,
#  1953033.0,
#  362624.0,
#  1616364.0,
#  424197.0,
#  1590421.0,
#  2011180.0,
#  1888696.0,
#  1470120.0,
#  2260973.0,
#  1625306.0,
#  105490.0,
#  1555057.0,
#  2256916.0,
#  1376403.0,
#  82268.0,
#  1957758.0,
#  491802.0,
#  1851017.0,
#  267531.0,
#  245157.0,
#  574338.0,
#  2509157.0,
#  2483304.0,
#  2208504.0,
#  1172030.0,
#  630546.0,
#  628491.0,
#  1236377.0,
#  1134240.0,
#  1335456.0,
#  2096481.0,
#  64019.0,
#  58249.0,
#  1825037.0,
#  2472507.0,
#  18829.0,
#  2529661.0,
#  281517.0,
#  1793942.0,
#  2028264.0,
#  2368264.0,
#  1232196.0,
#  1659603.0,
#  855334.0,
#  1107018.0,
#  1625463.0,
#  1587718.0,
#  1507373.0,
#  1862849.0,
#  874809.0,
#  938406.0,
#  1895776.0,
#  538533.0,
#  2158220.0,
#  1007029.0,
#  409610.0,
#  1783495.0,
#  1561359.0,
#  2423413.0,
#  1967521.0,
#  1654665.0,
#  1203331.0,
#  1356786.0,
#  479283.0,
#  2355621.0,
#  2488194.0,
#  2094445.0,
#  1496322.0,
#  1637857.0,
#  603633.0,
#  2433685.0,
#  1314177.0,
#  2503950.0,
#  1131042.0,
#  821498.0,
#  1951633.0,
#  1854342.0,
#  1925972.0,
#  2207896.0,
#  1406137.0,
#  1703469.0,
#  490256.0,
#  1899098.0,
#  2231763.0,
#  972327.0,
#  1817220.0,
#  1307299.0,
#  1152049.0,
#  645446.0,
#  2367171.0,
#  758067.0,
#  1227264.0,
#  2244196.0,
#  1078949.0,
#  92880.0,
#  341700.0,
#  1934229.0,
#  1221000.0,
#  404726.0,
#  1078270.0,
#  1093573.0,
#  1652364.0,
#  1669688.0,
#  2264142.0,
#  1123286.0,
#  1384873.0,
#  382785.0,
#  753150.0,
#  2193559.0,
#  564519.0,
#  206108.0,
#  653775.0,
#  506101.0,
#  1981955.0,
#  585214.0,
#  2454595.0,
#  1520012.0,
#  1636288.0,
#  306764.0,
#  2477222.0,
#  278958.0,
#  2108886.0,
#  1639436.0,
#  810666.0,
#  603904.0,
#  242094.0,
#  2073141.0,
#  1233775.0,
#  1403426.0,
#  2104717.0,
#  791009.0,
#  1624162.0,
#  821241.0,
#  1207130.0,
#  2359938.0,
#  1193141.0,
#  1811828.0,
#  402243.0,
#  1648762.0,
#  453900.0,
#  1711369.0,
#  1288606.0,
#  1898758.0,
#  300290.0,
#  665757.0,
#  1112632.0,
#  1586403.0,
#  1786683.0,
#  1606059.0,
#  733803.0,
#  573210.0,
#  971781.0,
#  790067.0,
#  1305497.0,
#  907627.0,
#  1140230.0,
#  2365341.0,
#  2396375.0,
#  1216809.0,
#  715054.0,
#  1661584.0,
#  615941.0,
#  40714.0,
#  291574.0,
#  1508290.0,
#  129960.0,
#  1051517.0,
#  499681.0,
#  1948078.0,
#  887141.0,
#  1287.0,
#  2143238.0,
#  1116661.0,
#  487293.0,
#  1297969.0,
#  2039367.0,
#  655110.0,
#  1018451.0,
#  1952399.0,
#  1129717.0,
#  1761848.0,
#  1323429.0,
#  1302206.0,
#  583648.0,
#  2466650.0,
#  1736591.0,
#  549706.0,
#  1257828.0,
#  2525217.0,
#  1210938.0,
#  148231.0,
#  328407.0,
#  2221442.0,
#  1376297.0,
#  412434.0,
#  1506781.0,
#  683320.0,
#  1716936.0,
#  1382329.0,
#  2199328.0,
#  2365326.0,
#  2332439.0,
#  2298318.0,
#  1322677.0,
#  1650769.0,
#  1575193.0,
#  2006792.0,
#  532454.0,
#  1469025.0,
#  609597.0,
#  2382355.0,
#  536466.0,
#  2233265.0,
#  338618.0,
#  1468731.0,
#  951171.0,
#  589752.0,
#  440533.0,
#  2210957.0,
#  925521.0,
#  1151263.0,
#  2041218.0,
#  1629349.0,
#  244841.0,
#  2224317.0,
#  1841983.0,
#  1022378.0,
#  1980616.0,
#  76367.0,
#  2498597.0,
#  2047588.0,
#  797771.0,
#  2323312.0,
#  ...]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (70860, 15)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1,1)

# %%
# creating the model
class BaselineModel(nn.Module):
  def __init__(self):
    super(BaselineModel, self).__init__()
    self.fc1 = nn.Linear(15, 512)
    self.fc2 = nn.Linear(512, 512)
    self.fc3 = nn.Linear(512, 64)
    self.fc4 = nn.Linear(64, 1)
    self.relu = nn.ReLU()
    self.dropout = nn.Dropout(0.3)

  def forward(self, x):
    x = self.relu(self.fc1(x))
    x = self.dropout(x)
    x = self.relu(self.fc2(x))
    x = self.dropout(x)
    x = self.relu(self.fc3(x))
    x = self.fc4(x)
    return x

model = BaselineModel()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 100
batch_size = 32
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# Training the Model

train_losses, test_losses, train_accuracies, test_accuracies, train_errors, test_errors = [], [], [], [], [], []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for batch_X, batch_y in train_loader:
        predictions = model(batch_X)
        loss = criterion(predictions, batch_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_loader)

    model.eval()
    with torch.no_grad():
        test_predictions = model(X_test)
        test_loss = criterion(test_predictions, y_test).item()

        train_predictions = model(X_train)
        train_rmse = root_mean_squared_error(y_train.numpy(), train_predictions.numpy())
        test_rmse = root_mean_squared_error(y_test.numpy(), test_predictions.numpy())

        train_nrmse = train_rmse/(y_train.max() - y_train.min())
        test_nrmse = test_rmse/(y_test.max() - y_test.min())

        train_accuracy = (1 - train_nrmse)*100
        test_accuracy = (1 - test_nrmse)*100


    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_errors.append(train_rmse)
    test_errors.append(test_rmse)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}]")
        print(f"  Training Loss: {train_loss:.4f}, Testing Loss: {test_loss:.4f}")
        print(f"  RMSE Error(Training): {train_rmse:.2f}, RMSE Error(Testing): {test_rmse:.2f}")
# Out:
# Epoch [10/100]
#   Training Loss: 9481121510.2844, Testing Loss: 9447901184.0000
#   RMSE Error(Training): 96211.08, RMSE Error(Testing): 97200.31
# Epoch [20/100]
#   Training Loss: 7794845830.6456, Testing Loss: 7248079872.0000
#   RMSE Error(Training): 83950.71, RMSE Error(Testing): 85135.66
# Epoch [30/100]
#   Training Loss: 7070773222.2266, Testing Loss: 6788792832.0000
#   RMSE Error(Training): 81115.48, RMSE Error(Testing): 82394.13
# Epoch [40/100]
#   Training Loss: 6828210427.1458, Testing Loss: 6626052608.0000
#   RMSE Error(Training): 80255.16, RMSE Error(Testing): 81400.57
# Epoch [50/100]
#   Training Loss: 6724125241.7300, Testing Loss: 6496024064.0000
#   RMSE Error(Training): 79356.84, RMSE Error(Testing): 80597.92
# Epoch [60/100]
#   Training Loss: 6618368185.9612, Testing Loss: 6439518208.0000
#   RMSE Error(Training): 78935.87, RMSE Error(Testing): 80246.61
# Epoch [70/100]
#   Training Loss: 6543059038.5986, Testing Loss: 6385605632.0000
#   RMSE Error(Training): 78555.80, RMSE Error(Testing): 79909.98
# Epoch [80/100]
#   Training Loss: 6512797109.5693, Testing Loss: 6376871936.0000
#   RMSE Error(Training): 78435.05, RMSE Error(Testing): 79855.32
# Epoch [90/100]
#   Training Loss: 6473925308.7928, Testing Loss: 6380389376.0000
#   RMSE Error(Training): 78377.86, RMSE Error(Testing): 79877.34
# Epoch [100/100]
#   Training Loss: 6467017154.3982, Testing Loss: 6349458432.0000
#   RMSE Error(Training): 78044.88, RMSE Error(Testing): 79683.49

# %%
plt.plot(train_accuracies, label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel(' Train Accuracy')
# Out:
# Text(0, 0.5, ' Train Accuracy')

# %%
plt.plot(test_accuracies, label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy')
# Out:
# Text(0, 0.5, 'Test Accuracy')

# %%
plt.plot(train_losses, label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
# Out:
# Text(0, 0.5, 'Train Loss')

# %%
plt.plot(test_losses, label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
# Out:
# Text(0, 0.5, 'Test Loss')

# %%
summary(model, (15,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]           8,192
#               ReLU-2                  [-1, 512]               0
#            Dropout-3                  [-1, 512]               0
#             Linear-4                  [-1, 512]         262,656
#               ReLU-5                  [-1, 512]               0
#            Dropout-6                  [-1, 512]               0
#             Linear-7                   [-1, 64]          32,832
#               ReLU-8                   [-1, 64]               0
#             Linear-9                    [-1, 1]              65
# ================================================================
# Total params: 303,745
# Trainable params: 303,745
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 1.16
# Estimated Total Size (MB): 1.18
# ----------------------------------------------------------------

# %% [markdown]
# ### Implementing the SISA Training Algorithm

# %%
# Using dataclasses to define Shard and Slice as a seperate datastructure to efficiently store information about them.
from dataclasses import dataclass


@dataclass
class Shard:
    shard_index: int
    x_shard: torch.tensor
    y_shard: torch.tensor

@dataclass
class Slice:
    shard_index: int
    slice_index: int
    x_slice: torch.tensor
    y_slice: torch.tensor

# Creates the shards of the data and returns a list of Shards
def create_shards(x, y, num_shards):
    shard_size = len(x) // num_shards
    shards = [
        Shard(
            shard_index=i,
            x_shard=x[i * shard_size:(i + 1) * shard_size],
            y_shard=y[i * shard_size:(i + 1) * shard_size]
        )
        for i in range(num_shards)
    ]
    return shards
# creates the slices of the given shard and returns a list of slices
def create_slices(shard, num_slices):
    x, y = shard.x_shard, shard.y_shard
    slice_size = len(x) // num_slices
    slices = [
        Slice(
            shard_index=shard.shard_index,  # Track which shard this slice belongs to
            slice_index=i,                 # Track which slice it is within the shard
            x_slice=x[i * slice_size:(i + 1) * slice_size],
            y_slice=y[i * slice_size:(i + 1) * slice_size]
        )
        for i in range(num_slices)
    ]
    return slices

# %%
# creating shards and slices of the training and the testing datasets
num_shards = 30
num_slices = 25
print(X_train.shape)
# for training data
train_shards = create_shards(X_train, y_train, num_shards)
train_slices = [
    create_slices(shard, num_slices)
    for shard in train_shards
]

# for testing data
test_shards = create_shards(X_test, y_test, num_shards)
test_slices = [
    create_slices(shard, num_slices)
    for shard in test_shards
]
print(X_train.shape)
# Out:
# torch.Size([70860, 15])
# torch.Size([70860, 15])

# %%
# creating a data class which will store the model and the shard it belongs to

@dataclass
class shard_model:
    shard_index: int
    model: nn.Module
    model_params: list

shard_models = []
for shard_idx in range(num_shards):
      # define the model for the shard
      model = BaselineModel()
      criterion = nn.MSELoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      num_epochs = 100
      BATCH_SIZE = 32
      X_train = 0
      y_train = 0
      model_params = []
      for slice_idx in range(num_slices):
            '''Train the model for the shard on slice 1, then on the union of slice 1 and 2 and so on'''
            if slice_idx == 0:
                  X_train = train_slices[shard_idx][slice_idx].x_slice
                  y_train = train_slices[shard_idx][slice_idx].y_slice
            else:
                  X_train = torch.cat((X_train, train_slices[shard_idx][slice_idx].x_slice))
                  y_train = torch.cat((y_train, train_slices[shard_idx][slice_idx].y_slice))
            train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
            train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
              
            # training the model
            for epoch in range(num_epochs):
                  model.train()
                  for batch_X, batch_y in train_loader:
                        predictions = model(batch_X)
                        loss = criterion(predictions, batch_y)
                          
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
            model_params.append(model.state_dict())
            print('Shard:- {0}, Slice:- {1}'.format(shard_idx, slice_idx))
      Model = shard_model(shard_idx, model, model_params)
      shard_models.append(Model)
# Out:
# Shard:- 0, Slice:- 0
# Shard:- 0, Slice:- 1
# Shard:- 0, Slice:- 2
# Shard:- 0, Slice:- 3
# Shard:- 0, Slice:- 4
# Shard:- 0, Slice:- 5
# Shard:- 0, Slice:- 6
# Shard:- 0, Slice:- 7
# Shard:- 0, Slice:- 8
# Shard:- 0, Slice:- 9
# Shard:- 0, Slice:- 10
# Shard:- 0, Slice:- 11
# Shard:- 0, Slice:- 12
# Shard:- 0, Slice:- 13
# Shard:- 0, Slice:- 14
# Shard:- 0, Slice:- 15
# Shard:- 0, Slice:- 16
# Shard:- 0, Slice:- 17
# Shard:- 0, Slice:- 18
# Shard:- 0, Slice:- 19
# Shard:- 0, Slice:- 20
# Shard:- 0, Slice:- 21
# Shard:- 0, Slice:- 22
# Shard:- 0, Slice:- 23
# Shard:- 0, Slice:- 24
# Shard:- 1, Slice:- 0
# Shard:- 1, Slice:- 1
# Shard:- 1, Slice:- 2
# Shard:- 1, Slice:- 3
# Shard:- 1, Slice:- 4
# Shard:- 1, Slice:- 5
# Shard:- 1, Slice:- 6
# Shard:- 1, Slice:- 7
# Shard:- 1, Slice:- 8
# Shard:- 1, Slice:- 9
# Shard:- 1, Slice:- 10
# Shard:- 1, Slice:- 11
# Shard:- 1, Slice:- 12
# Shard:- 1, Slice:- 13
# Shard:- 1, Slice:- 14
# Shard:- 1, Slice:- 15
# Shard:- 1, Slice:- 16
# Shard:- 1, Slice:- 17
# Shard:- 1, Slice:- 18
# Shard:- 1, Slice:- 19
# Shard:- 1, Slice:- 20
# Shard:- 1, Slice:- 21
# Shard:- 1, Slice:- 22
# Shard:- 1, Slice:- 23
# Shard:- 1, Slice:- 24
# Shard:- 2, Slice:- 0
# Shard:- 2, Slice:- 1
# Shard:- 2, Slice:- 2
# Shard:- 2, Slice:- 3
# Shard:- 2, Slice:- 4
# Shard:- 2, Slice:- 5
# Shard:- 2, Slice:- 6
# Shard:- 2, Slice:- 7
# Shard:- 2, Slice:- 8
# Shard:- 2, Slice:- 9
# Shard:- 2, Slice:- 10
# Shard:- 2, Slice:- 11
# Shard:- 2, Slice:- 12
# Shard:- 2, Slice:- 13
# Shard:- 2, Slice:- 14
# Shard:- 2, Slice:- 15
# Shard:- 2, Slice:- 16
# Shard:- 2, Slice:- 17
# Shard:- 2, Slice:- 18
# Shard:- 2, Slice:- 19
# Shard:- 2, Slice:- 20
# Shard:- 2, Slice:- 21
# Shard:- 2, Slice:- 22
# Shard:- 2, Slice:- 23
# Shard:- 2, Slice:- 24
# Shard:- 3, Slice:- 0
# Shard:- 3, Slice:- 1
# Shard:- 3, Slice:- 2
# Shard:- 3, Slice:- 3
# Shard:- 3, Slice:- 4
# Shard:- 3, Slice:- 5
# Shard:- 3, Slice:- 6
# Shard:- 3, Slice:- 7
# Shard:- 3, Slice:- 8
# Shard:- 3, Slice:- 9
# Shard:- 3, Slice:- 10
# Shard:- 3, Slice:- 11
# Shard:- 3, Slice:- 12
# Shard:- 3, Slice:- 13
# Shard:- 3, Slice:- 14
# Shard:- 3, Slice:- 15
# Shard:- 3, Slice:- 16
# Shard:- 3, Slice:- 17
# Shard:- 3, Slice:- 18
# Shard:- 3, Slice:- 19
# Shard:- 3, Slice:- 20
# Shard:- 3, Slice:- 21
# Shard:- 3, Slice:- 22
# Shard:- 3, Slice:- 23
# Shard:- 3, Slice:- 24
# Shard:- 4, Slice:- 0
# Shard:- 4, Slice:- 1
# Shard:- 4, Slice:- 2
# Shard:- 4, Slice:- 3
# Shard:- 4, Slice:- 4
# Shard:- 4, Slice:- 5
# Shard:- 4, Slice:- 6
# Shard:- 4, Slice:- 7
# Shard:- 4, Slice:- 8
# Shard:- 4, Slice:- 9
# Shard:- 4, Slice:- 10
# Shard:- 4, Slice:- 11
# Shard:- 4, Slice:- 12
# Shard:- 4, Slice:- 13
# Shard:- 4, Slice:- 14
# Shard:- 4, Slice:- 15
# Shard:- 4, Slice:- 16
# Shard:- 4, Slice:- 17
# Shard:- 4, Slice:- 18
# Shard:- 4, Slice:- 19
# Shard:- 4, Slice:- 20
# Shard:- 4, Slice:- 21
# Shard:- 4, Slice:- 22
# Shard:- 4, Slice:- 23
# Shard:- 4, Slice:- 24
# Shard:- 5, Slice:- 0
# Shard:- 5, Slice:- 1
# Shard:- 5, Slice:- 2
# Shard:- 5, Slice:- 3
# Shard:- 5, Slice:- 4
# Shard:- 5, Slice:- 5
# Shard:- 5, Slice:- 6
# Shard:- 5, Slice:- 7
# Shard:- 5, Slice:- 8
# Shard:- 5, Slice:- 9
# Shard:- 5, Slice:- 10
# Shard:- 5, Slice:- 11
# Shard:- 5, Slice:- 12
# Shard:- 5, Slice:- 13
# Shard:- 5, Slice:- 14
# Shard:- 5, Slice:- 15
# Shard:- 5, Slice:- 16
# Shard:- 5, Slice:- 17
# Shard:- 5, Slice:- 18
# Shard:- 5, Slice:- 19
# Shard:- 5, Slice:- 20
# Shard:- 5, Slice:- 21
# Shard:- 5, Slice:- 22
# Shard:- 5, Slice:- 23
# Shard:- 5, Slice:- 24
# Shard:- 6, Slice:- 0
# Shard:- 6, Slice:- 1
# Shard:- 6, Slice:- 2
# Shard:- 6, Slice:- 3
# Shard:- 6, Slice:- 4
# Shard:- 6, Slice:- 5
# Shard:- 6, Slice:- 6
# Shard:- 6, Slice:- 7
# Shard:- 6, Slice:- 8
# Shard:- 6, Slice:- 9
# Shard:- 6, Slice:- 10
# Shard:- 6, Slice:- 11
# Shard:- 6, Slice:- 12
# Shard:- 6, Slice:- 13
# Shard:- 6, Slice:- 14
# Shard:- 6, Slice:- 15
# Shard:- 6, Slice:- 16
# Shard:- 6, Slice:- 17
# Shard:- 6, Slice:- 18
# Shard:- 6, Slice:- 19
# Shard:- 6, Slice:- 20
# Shard:- 6, Slice:- 21
# Shard:- 6, Slice:- 22
# Shard:- 6, Slice:- 23
# Shard:- 6, Slice:- 24
# Shard:- 7, Slice:- 0
# Shard:- 7, Slice:- 1
# Shard:- 7, Slice:- 2
# Shard:- 7, Slice:- 3
# Shard:- 7, Slice:- 4
# Shard:- 7, Slice:- 5
# Shard:- 7, Slice:- 6
# Shard:- 7, Slice:- 7
# Shard:- 7, Slice:- 8
# Shard:- 7, Slice:- 9
# Shard:- 7, Slice:- 10
# Shard:- 7, Slice:- 11
# Shard:- 7, Slice:- 12
# Shard:- 7, Slice:- 13
# Shard:- 7, Slice:- 14
# Shard:- 7, Slice:- 15
# Shard:- 7, Slice:- 16
# Shard:- 7, Slice:- 17
# Shard:- 7, Slice:- 18
# Shard:- 7, Slice:- 19
# Shard:- 7, Slice:- 20
# Shard:- 7, Slice:- 21
# Shard:- 7, Slice:- 22
# Shard:- 7, Slice:- 23
# Shard:- 7, Slice:- 24
# Shard:- 8, Slice:- 0
# Shard:- 8, Slice:- 1
# Shard:- 8, Slice:- 2
# Shard:- 8, Slice:- 3
# Shard:- 8, Slice:- 4
# Shard:- 8, Slice:- 5
# Shard:- 8, Slice:- 6
# Shard:- 8, Slice:- 7
# Shard:- 8, Slice:- 8
# Shard:- 8, Slice:- 9
# Shard:- 8, Slice:- 10
# Shard:- 8, Slice:- 11
# Shard:- 8, Slice:- 12
# Shard:- 8, Slice:- 13
# Shard:- 8, Slice:- 14
# Shard:- 8, Slice:- 15
# Shard:- 8, Slice:- 16
# Shard:- 8, Slice:- 17
# Shard:- 8, Slice:- 18
# Shard:- 8, Slice:- 19
# Shard:- 8, Slice:- 20
# Shard:- 8, Slice:- 21
# Shard:- 8, Slice:- 22
# Shard:- 8, Slice:- 23
# Shard:- 8, Slice:- 24
# Shard:- 9, Slice:- 0
# Shard:- 9, Slice:- 1
# Shard:- 9, Slice:- 2
# Shard:- 9, Slice:- 3
# Shard:- 9, Slice:- 4
# Shard:- 9, Slice:- 5
# Shard:- 9, Slice:- 6
# Shard:- 9, Slice:- 7
# Shard:- 9, Slice:- 8
# Shard:- 9, Slice:- 9
# Shard:- 9, Slice:- 10
# Shard:- 9, Slice:- 11
# Shard:- 9, Slice:- 12
# Shard:- 9, Slice:- 13
# Shard:- 9, Slice:- 14
# Shard:- 9, Slice:- 15
# Shard:- 9, Slice:- 16
# Shard:- 9, Slice:- 17
# Shard:- 9, Slice:- 18
# Shard:- 9, Slice:- 19
# Shard:- 9, Slice:- 20
# Shard:- 9, Slice:- 21
# Shard:- 9, Slice:- 22
# Shard:- 9, Slice:- 23
# Shard:- 9, Slice:- 24
# Shard:- 10, Slice:- 0
# Shard:- 10, Slice:- 1
# Shard:- 10, Slice:- 2
# Shard:- 10, Slice:- 3
# Shard:- 10, Slice:- 4
# Shard:- 10, Slice:- 5
# Shard:- 10, Slice:- 6
# Shard:- 10, Slice:- 7
# Shard:- 10, Slice:- 8
# Shard:- 10, Slice:- 9
# Shard:- 10, Slice:- 10
# Shard:- 10, Slice:- 11
# Shard:- 10, Slice:- 12
# Shard:- 10, Slice:- 13
# Shard:- 10, Slice:- 14
# Shard:- 10, Slice:- 15
# Shard:- 10, Slice:- 16
# Shard:- 10, Slice:- 17
# Shard:- 10, Slice:- 18
# Shard:- 10, Slice:- 19
# Shard:- 10, Slice:- 20
# Shard:- 10, Slice:- 21
# Shard:- 10, Slice:- 22
# Shard:- 10, Slice:- 23
# Shard:- 10, Slice:- 24
# Shard:- 11, Slice:- 0
# Shard:- 11, Slice:- 1
# Shard:- 11, Slice:- 2
# Shard:- 11, Slice:- 3
# Shard:- 11, Slice:- 4
# Shard:- 11, Slice:- 5
# Shard:- 11, Slice:- 6
# Shard:- 11, Slice:- 7
# Shard:- 11, Slice:- 8
# Shard:- 11, Slice:- 9
# Shard:- 11, Slice:- 10
# Shard:- 11, Slice:- 11
# Shard:- 11, Slice:- 12
# Shard:- 11, Slice:- 13
# Shard:- 11, Slice:- 14
# Shard:- 11, Slice:- 15
# Shard:- 11, Slice:- 16
# Shard:- 11, Slice:- 17
# Shard:- 11, Slice:- 18
# Shard:- 11, Slice:- 19
# Shard:- 11, Slice:- 20
# Shard:- 11, Slice:- 21
# Shard:- 11, Slice:- 22
# Shard:- 11, Slice:- 23
# Shard:- 11, Slice:- 24
# Shard:- 12, Slice:- 0
# Shard:- 12, Slice:- 1
# Shard:- 12, Slice:- 2
# Shard:- 12, Slice:- 3
# Shard:- 12, Slice:- 4
# Shard:- 12, Slice:- 5
# Shard:- 12, Slice:- 6
# Shard:- 12, Slice:- 7
# Shard:- 12, Slice:- 8
# Shard:- 12, Slice:- 9
# Shard:- 12, Slice:- 10
# Shard:- 12, Slice:- 11
# Shard:- 12, Slice:- 12
# Shard:- 12, Slice:- 13
# Shard:- 12, Slice:- 14
# Shard:- 12, Slice:- 15
# Shard:- 12, Slice:- 16
# Shard:- 12, Slice:- 17
# Shard:- 12, Slice:- 18
# Shard:- 12, Slice:- 19
# Shard:- 12, Slice:- 20
# Shard:- 12, Slice:- 21
# Shard:- 12, Slice:- 22
# Shard:- 12, Slice:- 23
# Shard:- 12, Slice:- 24
# Shard:- 13, Slice:- 0
# Shard:- 13, Slice:- 1
# Shard:- 13, Slice:- 2
# Shard:- 13, Slice:- 3
# Shard:- 13, Slice:- 4
# Shard:- 13, Slice:- 5
# Shard:- 13, Slice:- 6
# Shard:- 13, Slice:- 7
# Shard:- 13, Slice:- 8
# Shard:- 13, Slice:- 9
# Shard:- 13, Slice:- 10
# Shard:- 13, Slice:- 11
# Shard:- 13, Slice:- 12
# Shard:- 13, Slice:- 13
# Shard:- 13, Slice:- 14
# Shard:- 13, Slice:- 15
# Shard:- 13, Slice:- 16
# Shard:- 13, Slice:- 17
# Shard:- 13, Slice:- 18
# Shard:- 13, Slice:- 19
# Shard:- 13, Slice:- 20
# Shard:- 13, Slice:- 21
# Shard:- 13, Slice:- 22
# Shard:- 13, Slice:- 23
# Shard:- 13, Slice:- 24
# Shard:- 14, Slice:- 0
# Shard:- 14, Slice:- 1
# Shard:- 14, Slice:- 2
# Shard:- 14, Slice:- 3
# Shard:- 14, Slice:- 4
# Shard:- 14, Slice:- 5
# Shard:- 14, Slice:- 6
# Shard:- 14, Slice:- 7
# Shard:- 14, Slice:- 8
# Shard:- 14, Slice:- 9
# Shard:- 14, Slice:- 10
# Shard:- 14, Slice:- 11
# Shard:- 14, Slice:- 12
# Shard:- 14, Slice:- 13
# Shard:- 14, Slice:- 14
# Shard:- 14, Slice:- 15
# Shard:- 14, Slice:- 16
# Shard:- 14, Slice:- 17
# Shard:- 14, Slice:- 18
# Shard:- 14, Slice:- 19
# Shard:- 14, Slice:- 20
# Shard:- 14, Slice:- 21
# Shard:- 14, Slice:- 22
# Shard:- 14, Slice:- 23
# Shard:- 14, Slice:- 24
# Shard:- 15, Slice:- 0
# Shard:- 15, Slice:- 1
# Shard:- 15, Slice:- 2
# Shard:- 15, Slice:- 3
# Shard:- 15, Slice:- 4
# Shard:- 15, Slice:- 5
# Shard:- 15, Slice:- 6
# Shard:- 15, Slice:- 7
# Shard:- 15, Slice:- 8
# Shard:- 15, Slice:- 9
# Shard:- 15, Slice:- 10
# Shard:- 15, Slice:- 11
# Shard:- 15, Slice:- 12
# Shard:- 15, Slice:- 13
# Shard:- 15, Slice:- 14
# Shard:- 15, Slice:- 15
# Shard:- 15, Slice:- 16
# Shard:- 15, Slice:- 17
# Shard:- 15, Slice:- 18
# Shard:- 15, Slice:- 19
# Shard:- 15, Slice:- 20
# Shard:- 15, Slice:- 21
# Shard:- 15, Slice:- 22
# Shard:- 15, Slice:- 23
# Shard:- 15, Slice:- 24
# Shard:- 16, Slice:- 0
# Shard:- 16, Slice:- 1
# Shard:- 16, Slice:- 2
# Shard:- 16, Slice:- 3
# Shard:- 16, Slice:- 4
# Shard:- 16, Slice:- 5
# Shard:- 16, Slice:- 6
# Shard:- 16, Slice:- 7
# Shard:- 16, Slice:- 8
# Shard:- 16, Slice:- 9
# Shard:- 16, Slice:- 10
# Shard:- 16, Slice:- 11
# Shard:- 16, Slice:- 12
# Shard:- 16, Slice:- 13
# Shard:- 16, Slice:- 14
# Shard:- 16, Slice:- 15
# Shard:- 16, Slice:- 16
# Shard:- 16, Slice:- 17
# Shard:- 16, Slice:- 18
# Shard:- 16, Slice:- 19
# Shard:- 16, Slice:- 20
# Shard:- 16, Slice:- 21
# Shard:- 16, Slice:- 22
# Shard:- 16, Slice:- 23
# Shard:- 16, Slice:- 24
# Shard:- 17, Slice:- 0
# Shard:- 17, Slice:- 1
# Shard:- 17, Slice:- 2
# Shard:- 17, Slice:- 3
# Shard:- 17, Slice:- 4
# Shard:- 17, Slice:- 5
# Shard:- 17, Slice:- 6
# Shard:- 17, Slice:- 7
# Shard:- 17, Slice:- 8
# Shard:- 17, Slice:- 9
# Shard:- 17, Slice:- 10
# Shard:- 17, Slice:- 11
# Shard:- 17, Slice:- 12
# Shard:- 17, Slice:- 13
# Shard:- 17, Slice:- 14
# Shard:- 17, Slice:- 15
# Shard:- 17, Slice:- 16
# Shard:- 17, Slice:- 17
# Shard:- 17, Slice:- 18
# Shard:- 17, Slice:- 19
# Shard:- 17, Slice:- 20
# Shard:- 17, Slice:- 21
# Shard:- 17, Slice:- 22
# Shard:- 17, Slice:- 23
# Shard:- 17, Slice:- 24
# Shard:- 18, Slice:- 0
# Shard:- 18, Slice:- 1
# Shard:- 18, Slice:- 2
# Shard:- 18, Slice:- 3
# Shard:- 18, Slice:- 4
# Shard:- 18, Slice:- 5
# Shard:- 18, Slice:- 6
# Shard:- 18, Slice:- 7
# Shard:- 18, Slice:- 8
# Shard:- 18, Slice:- 9
# Shard:- 18, Slice:- 10
# Shard:- 18, Slice:- 11
# Shard:- 18, Slice:- 12
# Shard:- 18, Slice:- 13
# Shard:- 18, Slice:- 14
# Shard:- 18, Slice:- 15
# Shard:- 18, Slice:- 16
# Shard:- 18, Slice:- 17
# Shard:- 18, Slice:- 18
# Shard:- 18, Slice:- 19
# Shard:- 18, Slice:- 20
# Shard:- 18, Slice:- 21
# Shard:- 18, Slice:- 22
# Shard:- 18, Slice:- 23
# Shard:- 18, Slice:- 24
# Shard:- 19, Slice:- 0
# Shard:- 19, Slice:- 1
# Shard:- 19, Slice:- 2
# Shard:- 19, Slice:- 3
# Shard:- 19, Slice:- 4
# Shard:- 19, Slice:- 5
# Shard:- 19, Slice:- 6
# Shard:- 19, Slice:- 7
# Shard:- 19, Slice:- 8
# Shard:- 19, Slice:- 9
# Shard:- 19, Slice:- 10
# Shard:- 19, Slice:- 11
# Shard:- 19, Slice:- 12
# Shard:- 19, Slice:- 13
# Shard:- 19, Slice:- 14
# Shard:- 19, Slice:- 15
# Shard:- 19, Slice:- 16
# Shard:- 19, Slice:- 17
# Shard:- 19, Slice:- 18
# Shard:- 19, Slice:- 19
# Shard:- 19, Slice:- 20
# Shard:- 19, Slice:- 21
# Shard:- 19, Slice:- 22
# Shard:- 19, Slice:- 23
# Shard:- 19, Slice:- 24
# Shard:- 20, Slice:- 0
# Shard:- 20, Slice:- 1
# Shard:- 20, Slice:- 2
# Shard:- 20, Slice:- 3
# Shard:- 20, Slice:- 4
# Shard:- 20, Slice:- 5
# Shard:- 20, Slice:- 6
# Shard:- 20, Slice:- 7
# Shard:- 20, Slice:- 8
# Shard:- 20, Slice:- 9
# Shard:- 20, Slice:- 10
# Shard:- 20, Slice:- 11
# Shard:- 20, Slice:- 12
# Shard:- 20, Slice:- 13
# Shard:- 20, Slice:- 14
# Shard:- 20, Slice:- 15
# Shard:- 20, Slice:- 16
# Shard:- 20, Slice:- 17
# Shard:- 20, Slice:- 18
# Shard:- 20, Slice:- 19
# Shard:- 20, Slice:- 20
# Shard:- 20, Slice:- 21
# Shard:- 20, Slice:- 22
# Shard:- 20, Slice:- 23
# Shard:- 20, Slice:- 24
# Shard:- 21, Slice:- 0
# Shard:- 21, Slice:- 1
# Shard:- 21, Slice:- 2
# Shard:- 21, Slice:- 3
# Shard:- 21, Slice:- 4
# Shard:- 21, Slice:- 5
# Shard:- 21, Slice:- 6
# Shard:- 21, Slice:- 7
# Shard:- 21, Slice:- 8
# Shard:- 21, Slice:- 9
# Shard:- 21, Slice:- 10
# Shard:- 21, Slice:- 11
# Shard:- 21, Slice:- 12
# Shard:- 21, Slice:- 13
# Shard:- 21, Slice:- 14
# Shard:- 21, Slice:- 15
# Shard:- 21, Slice:- 16
# Shard:- 21, Slice:- 17
# Shard:- 21, Slice:- 18
# Shard:- 21, Slice:- 19
# Shard:- 21, Slice:- 20
# Shard:- 21, Slice:- 21
# Shard:- 21, Slice:- 22
# Shard:- 21, Slice:- 23
# Shard:- 21, Slice:- 24
# Shard:- 22, Slice:- 0
# Shard:- 22, Slice:- 1
# Shard:- 22, Slice:- 2
# Shard:- 22, Slice:- 3
# Shard:- 22, Slice:- 4
# Shard:- 22, Slice:- 5
# Shard:- 22, Slice:- 6
# Shard:- 22, Slice:- 7
# Shard:- 22, Slice:- 8
# Shard:- 22, Slice:- 9
# Shard:- 22, Slice:- 10
# Shard:- 22, Slice:- 11
# Shard:- 22, Slice:- 12
# Shard:- 22, Slice:- 13
# Shard:- 22, Slice:- 14
# Shard:- 22, Slice:- 15
# Shard:- 22, Slice:- 16
# Shard:- 22, Slice:- 17
# Shard:- 22, Slice:- 18
# Shard:- 22, Slice:- 19
# Shard:- 22, Slice:- 20
# Shard:- 22, Slice:- 21
# Shard:- 22, Slice:- 22
# Shard:- 22, Slice:- 23
# Shard:- 22, Slice:- 24
# Shard:- 23, Slice:- 0
# Shard:- 23, Slice:- 1
# Shard:- 23, Slice:- 2
# Shard:- 23, Slice:- 3
# Shard:- 23, Slice:- 4
# Shard:- 23, Slice:- 5
# Shard:- 23, Slice:- 6
# Shard:- 23, Slice:- 7
# Shard:- 23, Slice:- 8
# Shard:- 23, Slice:- 9
# Shard:- 23, Slice:- 10
# Shard:- 23, Slice:- 11
# Shard:- 23, Slice:- 12
# Shard:- 23, Slice:- 13
# Shard:- 23, Slice:- 14
# Shard:- 23, Slice:- 15
# Shard:- 23, Slice:- 16
# Shard:- 23, Slice:- 17
# Shard:- 23, Slice:- 18
# Shard:- 23, Slice:- 19
# Shard:- 23, Slice:- 20
# Shard:- 23, Slice:- 21
# Shard:- 23, Slice:- 22
# Shard:- 23, Slice:- 23
# Shard:- 23, Slice:- 24
# Shard:- 24, Slice:- 0
# Shard:- 24, Slice:- 1
# Shard:- 24, Slice:- 2
# Shard:- 24, Slice:- 3
# Shard:- 24, Slice:- 4
# Shard:- 24, Slice:- 5
# Shard:- 24, Slice:- 6
# Shard:- 24, Slice:- 7
# Shard:- 24, Slice:- 8
# Shard:- 24, Slice:- 9
# Shard:- 24, Slice:- 10
# Shard:- 24, Slice:- 11
# Shard:- 24, Slice:- 12
# Shard:- 24, Slice:- 13
# Shard:- 24, Slice:- 14
# Shard:- 24, Slice:- 15
# Shard:- 24, Slice:- 16
# Shard:- 24, Slice:- 17
# Shard:- 24, Slice:- 18
# Shard:- 24, Slice:- 19
# Shard:- 24, Slice:- 20
# Shard:- 24, Slice:- 21
# Shard:- 24, Slice:- 22
# Shard:- 24, Slice:- 23
# Shard:- 24, Slice:- 24
# Shard:- 25, Slice:- 0
# Shard:- 25, Slice:- 1
# Shard:- 25, Slice:- 2
# Shard:- 25, Slice:- 3
# Shard:- 25, Slice:- 4
# Shard:- 25, Slice:- 5
# Shard:- 25, Slice:- 6
# Shard:- 25, Slice:- 7
# Shard:- 25, Slice:- 8
# Shard:- 25, Slice:- 9
# Shard:- 25, Slice:- 10
# Shard:- 25, Slice:- 11
# Shard:- 25, Slice:- 12
# Shard:- 25, Slice:- 13
# Shard:- 25, Slice:- 14
# Shard:- 25, Slice:- 15
# Shard:- 25, Slice:- 16
# Shard:- 25, Slice:- 17
# Shard:- 25, Slice:- 18
# Shard:- 25, Slice:- 19
# Shard:- 25, Slice:- 20
# Shard:- 25, Slice:- 21
# Shard:- 25, Slice:- 22
# Shard:- 25, Slice:- 23
# Shard:- 25, Slice:- 24
# Shard:- 26, Slice:- 0
# Shard:- 26, Slice:- 1
# Shard:- 26, Slice:- 2
# Shard:- 26, Slice:- 3
# Shard:- 26, Slice:- 4
# Shard:- 26, Slice:- 5
# Shard:- 26, Slice:- 6
# Shard:- 26, Slice:- 7
# Shard:- 26, Slice:- 8
# Shard:- 26, Slice:- 9
# Shard:- 26, Slice:- 10
# Shard:- 26, Slice:- 11
# Shard:- 26, Slice:- 12
# Shard:- 26, Slice:- 13
# Shard:- 26, Slice:- 14
# Shard:- 26, Slice:- 15
# Shard:- 26, Slice:- 16
# Shard:- 26, Slice:- 17
# Shard:- 26, Slice:- 18
# Shard:- 26, Slice:- 19
# Shard:- 26, Slice:- 20
# Shard:- 26, Slice:- 21
# Shard:- 26, Slice:- 22
# Shard:- 26, Slice:- 23
# Shard:- 26, Slice:- 24
# Shard:- 27, Slice:- 0
# Shard:- 27, Slice:- 1
# Shard:- 27, Slice:- 2
# Shard:- 27, Slice:- 3
# Shard:- 27, Slice:- 4
# Shard:- 27, Slice:- 5
# Shard:- 27, Slice:- 6
# Shard:- 27, Slice:- 7
# Shard:- 27, Slice:- 8
# Shard:- 27, Slice:- 9
# Shard:- 27, Slice:- 10
# Shard:- 27, Slice:- 11
# Shard:- 27, Slice:- 12
# Shard:- 27, Slice:- 13
# Shard:- 27, Slice:- 14
# Shard:- 27, Slice:- 15
# Shard:- 27, Slice:- 16
# Shard:- 27, Slice:- 17
# Shard:- 27, Slice:- 18
# Shard:- 27, Slice:- 19
# Shard:- 27, Slice:- 20
# Shard:- 27, Slice:- 21
# Shard:- 27, Slice:- 22
# Shard:- 27, Slice:- 23
# Shard:- 27, Slice:- 24
# Shard:- 28, Slice:- 0
# Shard:- 28, Slice:- 1
# Shard:- 28, Slice:- 2
# Shard:- 28, Slice:- 3
# Shard:- 28, Slice:- 4
# Shard:- 28, Slice:- 5
# Shard:- 28, Slice:- 6
# Shard:- 28, Slice:- 7
# Shard:- 28, Slice:- 8
# Shard:- 28, Slice:- 9
# Shard:- 28, Slice:- 10
# Shard:- 28, Slice:- 11
# Shard:- 28, Slice:- 12
# Shard:- 28, Slice:- 13
# Shard:- 28, Slice:- 14
# Shard:- 28, Slice:- 15
# Shard:- 28, Slice:- 16
# Shard:- 28, Slice:- 17
# Shard:- 28, Slice:- 18
# Shard:- 28, Slice:- 19
# Shard:- 28, Slice:- 20
# Shard:- 28, Slice:- 21
# Shard:- 28, Slice:- 22
# Shard:- 28, Slice:- 23
# Shard:- 28, Slice:- 24
# Shard:- 29, Slice:- 0
# Shard:- 29, Slice:- 1
# Shard:- 29, Slice:- 2
# Shard:- 29, Slice:- 3
# Shard:- 29, Slice:- 4
# Shard:- 29, Slice:- 5
# Shard:- 29, Slice:- 6
# Shard:- 29, Slice:- 7
# Shard:- 29, Slice:- 8
# Shard:- 29, Slice:- 9
# Shard:- 29, Slice:- 10
# Shard:- 29, Slice:- 11
# Shard:- 29, Slice:- 12
# Shard:- 29, Slice:- 13
# Shard:- 29, Slice:- 14
# Shard:- 29, Slice:- 15
# Shard:- 29, Slice:- 16
# Shard:- 29, Slice:- 17
# Shard:- 29, Slice:- 18
# Shard:- 29, Slice:- 19
# Shard:- 29, Slice:- 20
# Shard:- 29, Slice:- 21
# Shard:- 29, Slice:- 22
# Shard:- 29, Slice:- 23
# Shard:- 29, Slice:- 24

# %%
# getting the output by taking the mean of the output of the shard models
sharded_test_predictions = []
sharded_train_predictions = []
for shard_model in shard_models:
    test_pred = (shard_model.model(X_test)).detach().numpy()
    train_pred = (shard_model.model(X_train)).detach().numpy()
    sharded_test_predictions.append(test_pred)
    sharded_train_predictions.append(train_pred)

sharded_test_predictions = np.array(sharded_test_predictions)
sharded_train_predictions = np.array(sharded_train_predictions)
mean_test_predictions = np.mean(sharded_test_predictions, axis=0)
mean_train_predictions = np.mean(sharded_train_predictions, axis=0)

test_rmse = root_mean_squared_error(mean_test_predictions, y_test)
train_rmse = root_mean_squared_error(mean_train_predictions, y_train)

print(f"Train RMSE:- {train_rmse}")
print(f"Test RMSE:- {test_rmse}")
# Out:
# Train RMSE:- 82712.2421875
# Test RMSE:- 83654.1171875

# %%
l[1000]
# Out:
# 2194514.0

# %%
# To find the point to be deleted and to find the shard and the slice in which it belongs

def find_shard_slice(to_delete: torch.tensor, num_shards: int, num_slices: int, slices: list) -> tuple:
    '''Finds the shard index, slice index and index of the specific data point in the slice and returns them as a tuple'''
    for shard_idx in range(num_shards):
        for slice_idx in range(num_slices):
            for idx in range(len(slices[shard_idx][slice_idx].x_slice)):
                if torch.allclose(to_delete, train_slices[shard_idx][slice_idx].x_slice[idx]):
                   return (shard_idx, slice_idx, idx)

def del_data(shard_idx: int, slice_idx: int, idx: int, slices: list):
    '''Takes the shard index, slice index and the index of the data point and deletes it'''
    new_x_slice = torch.cat((slices[shard_idx][slice_idx].x_slice[:idx], slices[shard_idx][slice_idx].x_slice[idx+1:]))
    new_y_slice = torch.cat((slices[shard_idx][slice_idx].y_slice[:idx], slices[shard_idx][slice_idx].y_slice[idx+1:]))
    slices[shard_idx][slice_idx].x_slice = new_x_slice
    slices[shard_idx][slice_idx].y_slice = new_y_slice
    print(f"Data of shard {shard_idx} in slice {slice_idx} at index of {idx} deleted successfully")


pt_to_del = int(input("Enter record number to delete:- "))
df2 = df[features_list]
pt_to_del = df2[df['Record Number'] == pt_to_del].values
pt_to_del = torch.tensor(scaler.transform(pt_to_del)).to(torch.float32)
indices = find_shard_slice(pt_to_del, num_shards, num_slices, train_slices)
shard_idx_todel = indices[0]
slice_idx_todel = indices[1]
idx_todel = indices[2]
indices
del_data(shard_idx_todel, slice_idx_todel, idx_todel, train_slices)
# Out:
# Data of shard 0 in slice 10 at index of 60 deleted successfully

# %%
import torch.utils.data.dataloader


model = shard_models[shard_idx_todel].model 

if slice_idx_todel == 0:
    # if the first slice of shard has been changed then retrain the model from the beginning
    shard_models[shard_idx_todel].model_params = []
    unl_model_params = []
    for slice_idx in range(num_slices):
        if slice_idx == 0:
            x = train_slices[shard_idx_todel][0].x_slice
            y = train_slices[shard_idx_todel][0].y_slice
        else:
            x = torch.cat((x, train_slices[shard_idx_todel][slice_idx].x_slice))
            y = torch.cat((y, train_slices[shard_idx_todel][slice_idx].y_slice))
        train_dataset = torch.utils.data.TensorDataset(x, y)
        train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
              
        # training the model
        for epoch in range(num_epochs):
                model.train()
                for batch_X, batch_y in train_loader:
                    predictions = model(batch_X)
                    loss = criterion(predictions, batch_y)
                          
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
        unl_model_params.append(model.state_dict())
        print('Shard:- {0}, Slice:- {1}'.format(shard_idx_todel, slice_idx))
    shard_models[shard_idx_todel].model_params = unl_model_params

else:
    shard_models[shard_idx_todel].model_params = shard_models[shard_idx_todel].model_params[: slice_idx_todel - 1]
    unl_model_params = []

    for slice_idx in range(slice_idx_todel, num_slices):
        if slice_idx == slice_idx_todel:
            x = train_slices[shard_idx_todel][slice_idx].x_slice[:slice_idx + 1]
            y = train_slices[shard_idx_todel][slice_idx].y_slice[:slice_idx + 1]
        else:
            x = torch.cat([x, train_slices[shard_idx_todel][slice_idx].x_slice])
            y = torch.cat([y, train_slices[shard_idx_todel][slice_idx].y_slice])
        train_dataset = torch.utils.data.TensorDataset(x, y)
        train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

        for epoch in range(num_epochs):
            model.train()
            for batch_X, batch_y in train_loader:
                predictions = model(batch_X)
                loss = criterion(predictions, batch_y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        unl_model_params.append(model.state_dict())
        print('Shard:- {0}, Slice:- {1}'.format(shard_idx_todel, slice_idx))
    shard_models[shard_idx_todel].model_params[slice_idx_todel:] = unl_model_params

print('Unlearning Done Successfully')
# Out:
# Shard:- 0, Slice:- 10
# Shard:- 0, Slice:- 11
# Shard:- 0, Slice:- 12
# Shard:- 0, Slice:- 13
# Shard:- 0, Slice:- 14
# Shard:- 0, Slice:- 15
# Shard:- 0, Slice:- 16
# Shard:- 0, Slice:- 17
# Shard:- 0, Slice:- 18
# Shard:- 0, Slice:- 19
# Shard:- 0, Slice:- 20
# Shard:- 0, Slice:- 21
# Shard:- 0, Slice:- 22
# Shard:- 0, Slice:- 23
# Shard:- 0, Slice:- 24
# Unlearning Done Successfully

# %%
# Checking the RMSE of the new model
sharded_test_predictions = []
sharded_train_predictions = []
for shard_model in shard_models:
    test_pred = (shard_model.model(X_test)).detach().numpy()
    train_pred = (shard_model.model(X_train)).detach().numpy()
    sharded_test_predictions.append(test_pred)
    sharded_train_predictions.append(train_pred)

sharded_test_predictions = np.array(sharded_test_predictions)
sharded_train_predictions = np.array(sharded_train_predictions)
mean_test_predictions = np.mean(sharded_test_predictions, axis=0)
mean_train_predictions = np.mean(sharded_train_predictions, axis=0)

test_rmse = root_mean_squared_error(mean_test_predictions, y_test)
train_rmse = root_mean_squared_error(mean_train_predictions, y_train)

print(f"Train RMSE:- {train_rmse}")
print(f"Test RMSE:- {test_rmse}")
# Out:
# Train RMSE:- 83064.0859375
# Test RMSE:- 83199.515625
